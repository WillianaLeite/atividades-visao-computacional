# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Análise de textura

# %%
img = cv2.imread('lena.png',0) 
  
hist = cv2.calcHist([img],[0],None,[256],[0,256]) 
  
plt.plot(hist) 
plt.show()
